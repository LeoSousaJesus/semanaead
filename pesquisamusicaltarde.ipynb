# %% [markdown]
# # Atividade DataSet Pesquisa Musical

# %% [markdown]
# ## Importando o Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Importando o Numpy

# %%
import numpy as np

# %%
import seaborn as sns

# %% [markdown]
# ## Importando a planilha estilomusical.csv no Pandas

# %%
df_estilomusical = pd.read_csv('datasets/estilomusical.csv')

# %% [markdown]
# ## Mostrando o topo (5 primeiros no Dataframe)

# %%
df_estilomusical.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                     1                                 1
# 1                                     3                                 5
# 2                                     5                                 1
# 3                                     5                                 4
# 4                                     4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# ...

# %% [markdown]
# ## Mostrando as colunas do Dataframe

# %%
df_estilomusical.columns
# Out:
# Index(['Carimbo de data/hora', 'Avalie os estilos musicais [rock]',
#        'Avalie os estilos musicais [hip hop]',
#        'Avalie os estilos musicais [mpb]',
#        'Avalie os estilos musicais [reggae]',
#        'Avalie os estilos musicais [funk]',
#        'Avalie os estilos musicais [sertanejo]',
#        'Avalie os estilos musicais [gospel]',
#        'Avalie os estilos musicais [eletrônica]'],
#       dtype='object')

# %% [markdown]
# ## Apagando a primeira coluna (Carimbo de data/hora) do Dataframe

# %%
df_estilomusical = df_estilomusical.drop(columns=['Carimbo de data/hora'])

# %% [markdown]
# ## Mostrando o tipo do Dataframe

# %%
type(df_estilomusical)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Mostrando novamente o Dataframe sem a primeira coluna

# %%
df_estilomusical
# Out:
#     Avalie os estilos musicais [rock]  Avalie os estilos musicais [hip hop]  \
# 0                                   3                                     1
# 1                                   5                                     3
# 2                                   1                                     5
# 3                                   1                                     5
# 4                                   5                                     4
# 5                                   5                                     2
# 6                                   2                                     4
# 7                                   5                                     3
# 8                                   4                                     4
# 9                                   5                                     5
# 10                                  3                                     2
# ...

# %% [markdown]
# ## Renomaeando as colunas do Dataframe df_estilomusical

# %%
df_estilomusical = df_estilomusical.rename(columns={
    'Avalie os estilos musicais [rock]': 'Rock',
    'Avalie os estilos musicais [hip hop]': 'Hip Hop',
    'Avalie os estilos musicais [mpb]': 'MPB',
    'Avalie os estilos musicais [reggae]': 'Reggae',
    'Avalie os estilos musicais [funk]': 'Funk',
    'Avalie os estilos musicais [sertanejo]': 'Sertanejo',
    'Avalie os estilos musicais [gospel]': 'Gospel',
    'Avalie os estilos musicais [eletrônica]': 'Eletrônica'
})

# %% [markdown]
# ## Mostrando novamente o Dataframe com as colunas renomeadas

# %%
df_estilomusical
# Out:
#     Rock  Hip Hop  MPB  Reggae  Funk  Sertanejo  Gospel  Eletrônica
# 0      3        1    1       1     1          1       1           3
# 1      5        3    5       2     1          3       1           5
# 2      1        5    1       1     1          1       1           5
# 3      1        5    4       4     4          1       1           5
# 4      5        4    3       4     1          1       2           5
# 5      5        2    2       2     1          1       2           4
# 6      2        4    4       1     4          4       1           3
# 7      5        3    3       3     1          2       3           4
# 8      4        4    4       1     4          4       1           4
# 9      5        5    1       3     4          1       1           3
# 10     3        2    5       4     3          4       4           2
# 11     4        1    5       1     1          2       5           1
# 12     5        1    3       1     1          1       1           4
# ...

# %% [markdown]
# ## Importando matplotlib.pyplot para apresentação de gráficos e textos nos gráficos

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Apresentação dos dados em um gráfico de linhas

# %%
df_estilomusical.plot(kind='line')
plt.title('Gráfico de Linhas')
plt.xlabel('Índice')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# ## Apresentação dos dados em um gráfico de área

# %%
df_estilomusical.plot(kind='area')

# Exibir o gráfico
plt.title('Gráfico de Área')
plt.xlabel('Índice')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# ## Apresentação dos dados em um gráfico de barras

# %%
df_estilomusical.plot(kind='bar')
plt.title('Gráfico de Barras')
plt.xlabel('Índice')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# ## Apresentação dos dados em um gráfico de barras horizontais

# %%
soma=df_estilomusical.sum()

# %%
soma_notas.plot(kind='barh')
plt.title('Gráfico de Barras Horizontais')
plt.xlabel('Valores')
plt.ylabel('Índice')
plt.show()

# %% [markdown]
# ## Apresentação dos dados em um gráfico de pizza

# %%
soma_notas.plot(kind='pie', y='Índice')
plt.title('Gráfico de Pizza')
plt.ylabel('ìndice')  # Remove o rótulo do eixo y
plt.show()

# %% [markdown]
# ## Apresentação dos dados em um Histograma

# %%
sns.histplot(df_estilomusical,kde=True,bins=10)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Apresentação dos dados em um Histograma

# %%
df_estilomusical.plot(kind='hist', bins=10)

# Exibir o gráfico
plt.title('Histograma')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ## Usando Describe

# %%
df_estilomusical.describe()
# Out:
#             Rock    Hip Hop        MPB     Reggae       Funk  Sertanejo  \
# count  37.000000  37.000000  37.000000  37.000000  37.000000  37.000000
# mean    3.675676   3.216216   3.432432   2.378378   1.972973   2.513514
# std     1.415275   1.583511   1.344547   1.421098   1.404091   1.346221
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     3.000000   2.000000   3.000000   1.000000   1.000000   1.000000
# 50%     4.000000   4.000000   4.000000   2.000000   1.000000   3.000000
# 75%     5.000000   5.000000   4.000000   3.000000   3.000000   3.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#           Gospel  Eletrônica
# count  37.000000   37.000000
# mean    2.702703    3.297297
# std     1.578763    1.596261
# min     1.000000    1.000000
# 25%     1.000000    2.000000
# 50%     2.000000    4.000000
# 75%     4.000000    5.000000
# max     5.000000    5.000000

# %% [markdown]
# ## Apresentação dos dados em Boxplot

# %%
df_estilomusical.plot(kind='box')

# Exibir o gráfico
plt.title('Boxplot')
plt.show()

# %% [markdown]
# ## Definindo a variável para somar as notas

# %%
soma_notas = df_estilomusical.sum()

# %% [markdown]
# ## Apresentando o total de notas por estilo musical

# %%
soma_notas
# Out:
# Rock          136
# Hip Hop       119
# MPB           127
# Reggae         88
# Funk           73
# Sertanejo      93
# Gospel        100
# Eletrônica    122
# dtype: int64

# %% [markdown]
# ## Média das notas por estilo

# %%
df_estilomusical.mean()
# Out:
# Rock          3.675676
# Hip Hop       3.216216
# MPB           3.432432
# Reggae        2.378378
# Funk          1.972973
# Sertanejo     2.513514
# Gospel        2.702703
# Eletrônica    3.297297
# dtype: float64
